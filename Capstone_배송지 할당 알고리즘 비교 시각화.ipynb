# %%
import numpy as np, random, operator
import matplotlib.pyplot as plt
import pandas as pd
import folium

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
data = pd.read_csv(r'C:\Users\전종미\Desktop\종미 졸플 컴퓨터 자료\종미 졸플 컴퓨터 자료\한달치 휴리스틱 비교4.csv')

# %%
a = data['method1'].values.tolist()
b = data['method2'].values.tolist()
c = data['method3'].values.tolist()
d = data['method4'].values.tolist()
date = data['date'].values.tolist()

# %%
plt.rcParams["figure.figsize"] = (11,7)

# %%
from matplotlib import colors as mcolors


colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

plt.plot(date,a,color='silver',label='인접 거래처 할당 방법',linewidth=2.0)
plt.plot(date,b,color='silver',label='단위시간 당 외주택배비용 할당 방법',linewidth=2.0)
plt.plot(date,c,marker='o',color='teal',label='Transit time을 반영한 경유지 갱신 방법',linewidth=3.0)
plt.plot(date,d,color='silver',label='Transit time과 외주택배비용을 반영한 할당 방법',linewidth=2.0)
plt.xticks(['11월1일','4월1일','5월6일'],['3월','4월','5월'])
#plt.axis(option='auto')
plt.grid(b=True,which='both',axis='both')
plt.xlabel('Date')
plt.ylabel('Save cost')

plt.legend()
plt.show()
